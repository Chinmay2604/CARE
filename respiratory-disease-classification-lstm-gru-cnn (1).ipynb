# %%
import os

import wave
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import Audio
import librosa
import librosa.display
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv1D, Conv2D, SeparableConv1D, MaxPooling1D, MaxPooling2D
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import cohen_kappa_score,roc_auc_score,confusion_matrix,classification_report

# %%
audio_data = r"D:\Respiratory_Sound_Database\Respiratory_Sound_Database\AUDIOS"

# %%
patient_data=pd.read_csv(r"D:\Respiratory_Sound_Database\Respiratory_Sound_Database\patient_diagnosis.csv",names=['pid','disease'])

# %%
diagnosis_df = pd.read_csv(r"D:\Respiratory_Sound_Database\Respiratory_Sound_Database\patient_diagnosis.csv", names=['patient_id', 'disease'])
diagnosis_df.head(10)
# Out:
#    patient_id  disease
# 0         101     URTI
# 1         102  Healthy
# 2         103   Asthma
# 3         104     COPD
# 4         105     URTI
# 5         106     COPD
# 6         107     COPD
# 7         108     LRTI
# 8         109     COPD
# 9         110     COPD

# %%
print (diagnosis_df.disease.value_counts())
print ('')
print (diagnosis_df.disease.value_counts(normalize=True) *100)
# Out:
# disease
# COPD              64
# Healthy           26
# URTI              14
# Bronchiectasis     7
# Pneumonia          6
# Bronchiolitis      6
# LRTI               2
# Asthma             1
# Name: count, dtype: int64
#
# disease
# COPD              50.793651
# Healthy           20.634921
# URTI              11.111111
# Bronchiectasis     5.555556
# Pneumonia          4.761905
# Bronchiolitis      4.761905
# LRTI               1.587302
# Asthma             0.793651
# Name: proportion, dtype: float64

# %%
sns.countplot(x='disease', hue='disease', data=diagnosis_df)
plt.grid(axis='y', color='green', linestyle='--', linewidth=0.5)
plt.xticks(rotation=90) 
plt.show()

# %%
path=r"D:\Respiratory_Sound_Database\Respiratory_Sound_Database\AUDIOS"
files=[s.split('.')[0] for s in os.listdir(path) if '.txt' in s]

# %%
files[:15]
# Out:
# []

# %%
print(f"Librosa version: {librosa.__version__}")
print(f"Librosa location: {librosa.__file__}")
# Out:
# Librosa version: 0.10.2.post1
# Librosa location: c:\Users\prith\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\__init__.py

# %%
def add_noise(data,x):
    noise = np.random.randn(len(data))
    data_noise = data + x * noise
    return data_noise

def shift(data,x):
    return np.roll(data, x)

def stretch(data, rate):
    data = librosa.effects.time_stretch(data, rate=1.0)
    return data

def pitch_shift (data , rate):
    data = librosa.effects.pitch_shift(data, sr=220250, n_steps=rate)
    return data

# %%
def show_audio(audio_path):
    y, sr = librosa.load(audio_path)
    y_noise = add_noise(y , 0.0008)
    y_shift = shift(y,3200)
    y_stretch_1 = stretch(y, 1.2)
    y_stretch_2 = stretch(y, 0.8)
    y_pitch_shift = pitch_shift(y, 3)
    
    plt.figure(figsize=(20, 8))
    
    plt.subplot(3,2,1)
    librosa.display.waveshow(y, sr=sr)
    plt.title('orginal')

    plt.subplot(3,2,2)
    librosa.display.waveshow(y_noise, sr=sr)
    plt.title('noise')

    plt.subplot(3,2,3)
    librosa.display.waveshow(y_shift, sr=sr)
    plt.title('shift')
    
    plt.subplot(3,2,4)
    librosa.display.waveshow(y_stretch_1, sr=sr)
    plt.title('stretch 1')
    
    plt.subplot(3,2,5)
    librosa.display.waveshow(y_stretch_2, sr=sr)
    plt.title('stretch 2')
    
    plt.subplot(3,2,6)
    librosa.display.waveshow(y_pitch_shift, sr=sr)
    plt.title('pitch shift')

    plt.tight_layout()

# %%
show_audio(r"D:\Respiratory_Sound_Database\Respiratory_Sound_Database\AUDIOS\104_1b1_Ar_sc_Litt3200.wav")

# %%
def show_audio_features(audio_path):
    y, sr = librosa.load(audio_path)
    y_noise = add_noise(y , 0.0008)
    y_shift = shift(y,3200)
    y_stretch_1 = stretch(y, 1.2)
    y_stretch_2 = stretch(y, 0.8)
    y_pitch_shift = pitch_shift(y, 3)
    
    y = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=50)
    y_noise = librosa.feature.mfcc(y=y_noise, sr=sr, n_mfcc=50)
    y_shift = librosa.feature.mfcc(y=y_shift, sr=sr, n_mfcc=50)
    y_stretch_1 = librosa.feature.mfcc(y=y_stretch_1, sr=sr, n_mfcc=50)
    y_stretch_2 = librosa.feature.mfcc(y=y_stretch_2, sr=sr, n_mfcc=50)
    y_pitch_shift = librosa.feature.mfcc(y=y_pitch_shift, sr=sr, n_mfcc=50)
    
    plt.figure(figsize=(20, 8))
    
    plt.subplot(3,2,1)
    librosa.display.specshow(librosa.power_to_db(y,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('orginal')

    plt.subplot(3,2,2)
    librosa.display.specshow(librosa.power_to_db(y_noise,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('noise')

    plt.subplot(3,2,3)
    librosa.display.specshow(librosa.power_to_db(y_shift,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('shift')
    
    plt.subplot(3,2,4)
    librosa.display.specshow(librosa.power_to_db(y_stretch_1,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('stretch 1')
    
    plt.subplot(3,2,5)
    librosa.display.specshow(librosa.power_to_db(y_stretch_2,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('stretch 2')
    
    plt.subplot(3,2,6)
    librosa.display.specshow(librosa.power_to_db(y_pitch_shift,ref=np.max),
                             y_axis='mel',
                             fmax=8000,
                             x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('pitch shift')
    
    

    plt.tight_layout()

# %%
show_audio_features(r"D:\Respiratory_Sound_Database\Respiratory_Sound_Database\AUDIOS\104_1b1_Ar_sc_Litt3200.wav")

# %%
def mfccs_feature_exteraction(dir_):
    X_ = []
    y_ = []
    COPD = []
    copd_count = 0

    data = diagnosis_df
    features = 52

    for soundDir in os.listdir(dir_):
        if soundDir.endswith('.wav') and soundDir[:3] not in ['103', '108', '115']:
            full_path = os.path.join(dir_, soundDir)

            try:
                # Get disease label
                p = list(data[data['patient_id'] == int(soundDir[:3])]['disease'])[0]

                if p == 'COPD':
                    if (soundDir[:6] in COPD) and copd_count < 2:
                        data_x, sampling_rate = librosa.load(full_path, res_type='kaiser_fast')
                        mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T, axis=0)
                        COPD.append(soundDir[:6])
                        copd_count += 1
                        X_.append(mfccs)
                        y_.append(p)
                    elif (soundDir[:6] not in COPD):
                        data_x, sampling_rate = librosa.load(full_path, res_type='kaiser_fast')
                        mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T, axis=0)
                        COPD.append(soundDir[:6])
                        copd_count = 0
                        X_.append(mfccs)
                        y_.append(p)

                else:
                    data_x, sampling_rate = librosa.load(full_path, res_type='kaiser_fast')
                    if p in ['Bronchiectasis', 'Bronchiolitis']:
                        p = 'Bronchiolitis'

                    # Original
                    mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T, axis=0)
                    X_.append(mfccs)
                    y_.append(p)

                    # Noise
                    data_noise = add_noise(data_x, 0.001)
                    mfccs_noise = np.mean(librosa.feature.mfcc(y=data_noise, sr=sampling_rate, n_mfcc=features).T, axis=0)
                    X_.append(mfccs_noise)
                    y_.append(p)

                    # Shift
                    data_shift = shift(data_x, 1600)
                    mfccs_shift = np.mean(librosa.feature.mfcc(y=data_shift, sr=sampling_rate, n_mfcc=features).T, axis=0)
                    X_.append(mfccs_shift)
                    y_.append(p)

                    # Stretch 1
                    data_stretch = stretch(data_x, 1.2)
                    mfccs_stretch = np.mean(librosa.feature.mfcc(y=data_stretch, sr=sampling_rate, n_mfcc=features).T, axis=0)
                    X_.append(mfccs_stretch)
                    y_.append(p)

                    # Stretch 2
                    data_stretch_2 = stretch(data_x, 0.8)
                    mfccs_stretch_2 = np.mean(librosa.feature.mfcc(y=data_stretch_2, sr=sampling_rate, n_mfcc=features).T, axis=0)
                    X_.append(mfccs_stretch_2)
                    y_.append(p)

                    # Pitch shift
                    data_pitch_shift = pitch_shift(data_x, 3)
                    mfccs_pitch = np.mean(librosa.feature.melspectrogram(y=data_pitch_shift, sr=sampling_rate, n_mels=features).T, axis=0)
                    X_.append(mfccs_pitch)
                    y_.append(p)

            except Exception as e:
                print(f"Error processing file {soundDir}: {e}")

    X_data = np.array(X_)
    y_data = np.array(y_)
    return X_data, y_data

# %%
x_mfccs, y = mfccs_feature_exteraction(audio_data)

# %%
def augmented_lables_count(lables):
    unique, counts = np.unique(lables, return_counts=True)
    data_count = dict(zip(unique, counts))

    data = data_count

    courses = list(data.keys())
    values = list(data.values())

    fig = plt.figure(figsize = (10, 5))

    # creating the bar plot
    plt.bar(courses, values, color =['orange','green','blue','red','yellow','black'],
            width = 0.4)

    plt.xlabel("Diseases")
    plt.ylabel("Count")
    plt.title("Count of each disease")
    plt.show()

    print (data_count)

# %%
augmented_lables_count(y)
# Out:
# {'Bronchiolitis': 174, 'COPD': 298, 'Healthy': 210, 'Pneumonia': 222, 'URTI': 138}

# %%
y_data_encode = y.reshape(y.shape[0],1)
y_data_encode = np.where(y_data_encode == 'COPD',np.array([1,0,0,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Bronchiolitis',np.array([0,1,0,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Pneumonia',np.array([0,0,1,0,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'URTI',np.array([0,0,0,1,0]).reshape(1,5) , y_data_encode)
y_data_encode = np.where(y_data_encode == 'Healthy',np.array([0,0,0,0,1]).reshape(1,5) , y_data_encode)

Y_data = y_data_encode.astype('float64')

# %%
mfccs_features = np.array(x_mfccs)
lables = np.array(Y_data)

mfccs_features.shape , lables.shape
# Out:
# ((1042, 52), (1042, 5))

# %%
mfcc_train, mfcc_val, lables_train, lables_val  = train_test_split(mfccs_features, lables, test_size=0.175, random_state=10)
mfcc_train, mfcc_test, lables_train, lables_test = train_test_split(mfcc_train, lables_train, test_size=0.075, random_state=10)

print (mfcc_train.shape, mfcc_val.shape, mfcc_test.shape)
print (lables_train.shape, lables_val.shape, lables_test.shape)
# Out:
# (794, 52) (183, 52) (65, 52)
# (794, 5) (183, 5) (65, 5)

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
#   plt.plot(epochs, loss, label='training_loss')
#   plt.plot(epochs, val_loss, label='val_loss')
#   plt.title('Loss')
#   plt.xlabel('Epochs')
#   plt.legend()
#   plt.grid()


  # Plot accuracy
  plt.figure()
  plt.grid()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
x_train_gru = np.expand_dims(mfcc_train,axis=1)
x_val_gru = np.expand_dims(mfcc_val,axis=1)
x_test_gru = np.expand_dims(mfcc_test,axis=1)

y_train_gru = np.expand_dims(lables_train,axis=1)
y_val_gru = np.expand_dims(lables_val,axis=1)
y_test_gru = np.expand_dims(lables_test,axis=1)

# %%
Input_Sample = Input(shape=(1,52))

model_conv = Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu')(Input_Sample)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_conv = Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu')(model_conv)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_2_1 = GRU(32,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_2 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_2_1)

model_3 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_3 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_3)

model_x = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_x = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_x)

model_add_1 = add([model_3,model_2,model_x])

model_5 = GRU(128,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_5 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_5)

model_6 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_6 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_6)

model_add_2 = add([model_5,model_6,model_2_1])


model_7 = Dense(32, activation=None)(model_add_2)
model_7 = LeakyReLU()(model_7)
model_7 = Dense(128, activation=None)(model_7)
model_7 = LeakyReLU()(model_7)

model_9 = Dense(64, activation=None)(model_add_2)
model_9 = LeakyReLU()(model_9)
model_9 = Dense(128, activation=None)(model_9)
model_9 = LeakyReLU()(model_9)

model_add_3 = add([model_7,model_9])

model_10 = Dense(64, activation=None)(model_add_3)
model_10 = LeakyReLU()(model_10)

model_10 = Dense(32, activation=None)(model_10)
model_10 = LeakyReLU()(model_10)

model_10 = Dense(5, activation="softmax")(model_10)

gru_model = Model(inputs=Input_Sample, outputs = model_10)

gru_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1, 52)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 1, 256)    │     66,816 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 1, 256)    │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1, 256)    │      1,024 │ max_pooling1d[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 1, 512)    │    655,872 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 1, 512)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 512)    │      2,048 │ max_pooling1d_1[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_2 (GRU)         │ (None, 1, 64)     │    110,976 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 1, 32)     │     52,416 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_4 (GRU)         │ (None, 1, 64)     │    110,976 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_3 (GRU)         │ (None, 1, 128)    │     74,496 │ gru_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_1 (GRU)         │ (None, 1, 128)    │     62,208 │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_5 (GRU)         │ (None, 1, 128)    │     74,496 │ gru_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 128)    │          0 │ gru_3[0][0],      │
# │                     │                   │            │ gru_1[0][0],      │
# │                     │                   │            │ gru_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_6 (GRU)         │ (None, 1, 128)    │     99,072 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_8 (GRU)         │ (None, 1, 64)     │     37,248 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_7 (GRU)         │ (None, 1, 32)     │     15,552 │ gru_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_9 (GRU)         │ (None, 1, 32)     │      9,408 │ gru_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 32)     │          0 │ gru_7[0][0],      │
# │                     │                   │            │ gru_9[0][0],      │
# │                     │                   │            │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 32)     │      1,056 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1, 64)     │      2,112 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 1, 32)     │          0 │ dense[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 1, 64)     │          0 │ dense_2[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 128)    │      4,224 │ leaky_re_lu[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1, 128)    │      8,320 │ leaky_re_lu_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 1, 128)    │          0 │ dense_1[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 1, 128)    │          0 │ dense_3[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 128)    │          0 │ leaky_re_lu_1[0]… │
# │                     │                   │            │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1, 64)     │      8,256 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 1, 64)     │          0 │ dense_4[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1, 32)     │      2,080 │ leaky_re_lu_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 1, 32)     │          0 │ dense_5[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1, 5)      │        165 │ leaky_re_lu_5[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,398,821 (5.34 MB)
#  Trainable params: 1,397,285 (5.33 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Define optimizer
optimiser = tf.keras.optimizers.Adam(learning_rate=0.0001)

# Compile the model
gru_model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['accuracy'])

# Update the file path to use .keras format
filepath = 'D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras'

# Callbacks with updated file extension
cb = [
    EarlyStopping(patience=300, monitor='val_accuracy', mode='max', restore_best_weights=True),  # Early stopping
    ModelCheckpoint(filepath=filepath, 
                    monitor='val_accuracy', 
                    save_best_only=True, 
                    mode='max', 
                    verbose=1)  # Model checkpoint
]

# %%
history = gru_model.fit(x_train_gru, y_train_gru, batch_size=8, epochs=50, validation_data=(x_val_gru, y_val_gru), callbacks = cb)
# Out:
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3175 - loss: 1.5092
# Epoch 1: val_accuracy improved from -inf to 0.30055, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 34s 64ms/step - accuracy: 0.3183 - loss: 1.5083 - val_accuracy: 0.3005 - val_loss: 1.5414
# Epoch 2/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5081 - loss: 1.2332
# Epoch 2: val_accuracy improved from 0.30055 to 0.55738, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5082 - loss: 1.2318 - val_accuracy: 0.5574 - val_loss: 1.2497
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5691 - loss: 1.0766
# Epoch 3: val_accuracy improved from 0.55738 to 0.57923, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5692 - loss: 1.0764 - val_accuracy: 0.5792 - val_loss: 1.0611
# Epoch 4/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5726 - loss: 1.0239
# Epoch 4: val_accuracy improved from 0.57923 to 0.65574, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5736 - loss: 1.0228 - val_accuracy: 0.6557 - val_loss: 0.9080
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6807 - loss: 0.8822
# Epoch 5: val_accuracy improved from 0.65574 to 0.66667, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6803 - loss: 0.8825 - val_accuracy: 0.6667 - val_loss: 0.8764
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6312 - loss: 0.8667
# Epoch 6: val_accuracy improved from 0.66667 to 0.70492, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6314 - loss: 0.8665 - val_accuracy: 0.7049 - val_loss: 0.7573
# Epoch 7/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6941 - loss: 0.8101
# Epoch 7: val_accuracy did not improve from 0.70492
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6938 - loss: 0.8102 - val_accuracy: 0.6831 - val_loss: 0.7300
# Epoch 8/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6703 - loss: 0.7804
# Epoch 8: val_accuracy did not improve from 0.70492
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6706 - loss: 0.7807 - val_accuracy: 0.6776 - val_loss: 0.7454
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6684 - loss: 0.8246
# Epoch 9: val_accuracy did not improve from 0.70492
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6686 - loss: 0.8244 - val_accuracy: 0.7049 - val_loss: 0.6922
# Epoch 10/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6994 - loss: 0.7715
# Epoch 10: val_accuracy did not improve from 0.70492
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6996 - loss: 0.7711 - val_accuracy: 0.7049 - val_loss: 0.6677
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7038 - loss: 0.7132
# Epoch 11: val_accuracy did not improve from 0.70492
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7037 - loss: 0.7136 - val_accuracy: 0.6940 - val_loss: 0.7648
# Epoch 12/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6868 - loss: 0.7636
# Epoch 12: val_accuracy improved from 0.70492 to 0.72678, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6869 - loss: 0.7631 - val_accuracy: 0.7268 - val_loss: 0.6318
# Epoch 13/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7402 - loss: 0.6856
# Epoch 13: val_accuracy did not improve from 0.72678
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7397 - loss: 0.6863 - val_accuracy: 0.6667 - val_loss: 0.7399
# Epoch 14/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7121 - loss: 0.6900
# Epoch 14: val_accuracy did not improve from 0.72678
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7121 - loss: 0.6903 - val_accuracy: 0.7104 - val_loss: 0.6200
# Epoch 15/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7206 - loss: 0.6817
# Epoch 15: val_accuracy did not improve from 0.72678
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7208 - loss: 0.6815 - val_accuracy: 0.7213 - val_loss: 0.6418
# Epoch 16/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7695 - loss: 0.6334
# Epoch 16: val_accuracy improved from 0.72678 to 0.75956, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7693 - loss: 0.6337 - val_accuracy: 0.7596 - val_loss: 0.5712
# Epoch 17/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7472 - loss: 0.6157
# Epoch 17: val_accuracy did not improve from 0.75956
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7471 - loss: 0.6161 - val_accuracy: 0.7432 - val_loss: 0.5609
# Epoch 18/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7367 - loss: 0.6689
# Epoch 18: val_accuracy did not improve from 0.75956
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7366 - loss: 0.6690 - val_accuracy: 0.7541 - val_loss: 0.5690
# Epoch 19/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7603 - loss: 0.6395
# Epoch 19: val_accuracy did not improve from 0.75956
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7603 - loss: 0.6394 - val_accuracy: 0.7377 - val_loss: 0.5741
# Epoch 20/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7607 - loss: 0.6035
# Epoch 20: val_accuracy did not improve from 0.75956
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7605 - loss: 0.6036 - val_accuracy: 0.7596 - val_loss: 0.5575
# Epoch 21/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7356 - loss: 0.6504
# Epoch 21: val_accuracy improved from 0.75956 to 0.77596, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7358 - loss: 0.6502 - val_accuracy: 0.7760 - val_loss: 0.5089
# Epoch 22/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7907 - loss: 0.5348
# Epoch 22: val_accuracy did not improve from 0.77596
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7907 - loss: 0.5349 - val_accuracy: 0.7596 - val_loss: 0.5743
# Epoch 23/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7861 - loss: 0.5592
# Epoch 23: val_accuracy did not improve from 0.77596
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7857 - loss: 0.5599 - val_accuracy: 0.7049 - val_loss: 0.6594
# Epoch 24/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7863 - loss: 0.5415
# Epoch 24: val_accuracy did not improve from 0.77596
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7859 - loss: 0.5416 - val_accuracy: 0.7541 - val_loss: 0.5594
# Epoch 25/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7730 - loss: 0.5357
# Epoch 25: val_accuracy improved from 0.77596 to 0.78689, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7731 - loss: 0.5356 - val_accuracy: 0.7869 - val_loss: 0.5324
# Epoch 26/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7991 - loss: 0.5357
# Epoch 26: val_accuracy improved from 0.78689 to 0.81967, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7984 - loss: 0.5365 - val_accuracy: 0.8197 - val_loss: 0.4551
# Epoch 27/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8165 - loss: 0.4875
# Epoch 27: val_accuracy improved from 0.81967 to 0.82514, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8159 - loss: 0.4888 - val_accuracy: 0.8251 - val_loss: 0.4459
# Epoch 28/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7634 - loss: 0.5740
# Epoch 28: val_accuracy did not improve from 0.82514
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7643 - loss: 0.5725 - val_accuracy: 0.7760 - val_loss: 0.5366
# Epoch 29/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7816 - loss: 0.5541
# Epoch 29: val_accuracy improved from 0.82514 to 0.84153, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7820 - loss: 0.5540 - val_accuracy: 0.8415 - val_loss: 0.4529
# Epoch 30/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8155 - loss: 0.4583
# Epoch 30: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8154 - loss: 0.4592 - val_accuracy: 0.8142 - val_loss: 0.5273
# Epoch 31/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7954 - loss: 0.5151
# Epoch 31: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7957 - loss: 0.5148 - val_accuracy: 0.8087 - val_loss: 0.4795
# Epoch 32/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7773 - loss: 0.5431
# Epoch 32: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7778 - loss: 0.5424 - val_accuracy: 0.8142 - val_loss: 0.4588
# Epoch 33/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8117 - loss: 0.5573
# Epoch 33: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8116 - loss: 0.5569 - val_accuracy: 0.7869 - val_loss: 0.4728
# Epoch 34/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7969 - loss: 0.4876
# Epoch 34: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7970 - loss: 0.4877 - val_accuracy: 0.8033 - val_loss: 0.5445
# Epoch 35/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8423 - loss: 0.4588
# Epoch 35: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8422 - loss: 0.4589 - val_accuracy: 0.7814 - val_loss: 0.5097
# Epoch 36/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8222 - loss: 0.4836
# Epoch 36: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8219 - loss: 0.4838 - val_accuracy: 0.7923 - val_loss: 0.4723
# Epoch 37/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8154 - loss: 0.4601
# Epoch 37: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8154 - loss: 0.4602 - val_accuracy: 0.7760 - val_loss: 0.5602
# Epoch 38/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8051 - loss: 0.5103
# Epoch 38: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8050 - loss: 0.5104 - val_accuracy: 0.7213 - val_loss: 0.7181
# Epoch 39/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8353 - loss: 0.4372
# Epoch 39: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8348 - loss: 0.4378 - val_accuracy: 0.8197 - val_loss: 0.4636
# Epoch 40/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8111 - loss: 0.4993
# Epoch 40: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8111 - loss: 0.4993 - val_accuracy: 0.8033 - val_loss: 0.4758
# Epoch 41/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8406 - loss: 0.4274
# Epoch 41: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8404 - loss: 0.4279 - val_accuracy: 0.8142 - val_loss: 0.5106
# Epoch 42/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7972 - loss: 0.4811
# Epoch 42: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7974 - loss: 0.4812 - val_accuracy: 0.7486 - val_loss: 0.6156
# Epoch 43/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8360 - loss: 0.4614
# Epoch 43: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8361 - loss: 0.4609 - val_accuracy: 0.8306 - val_loss: 0.3923
# Epoch 44/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8340 - loss: 0.4064
# Epoch 44: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8339 - loss: 0.4072 - val_accuracy: 0.8197 - val_loss: 0.4559
# Epoch 45/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8147 - loss: 0.4205
# Epoch 45: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8146 - loss: 0.4212 - val_accuracy: 0.8415 - val_loss: 0.4098
# Epoch 46/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8158 - loss: 0.4559
# Epoch 46: val_accuracy did not improve from 0.84153
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8164 - loss: 0.4550 - val_accuracy: 0.8197 - val_loss: 0.4279
# Epoch 47/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8257 - loss: 0.3984
# Epoch 47: val_accuracy improved from 0.84153 to 0.86339, saving model to D:/Respiratory_Sound_Database/diagnosis_GRU_CNN_1.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8255 - loss: 0.3992 - val_accuracy: 0.8634 - val_loss: 0.3721
# Epoch 48/50
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7769 - loss: 0.5568
# Epoch 48: val_accuracy did not improve from 0.86339
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7776 - loss: 0.5556 - val_accuracy: 0.8087 - val_loss: 0.4656
# Epoch 49/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8576 - loss: 0.4048
# Epoch 49: val_accuracy did not improve from 0.86339
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8575 - loss: 0.4052 - val_accuracy: 0.8087 - val_loss: 0.5016
# Epoch 50/50
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8362 - loss: 0.4356
# Epoch 50: val_accuracy did not improve from 0.86339
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8360 - loss: 0.4358 - val_accuracy: 0.8525 - val_loss: 0.4323

# %%
gru_model.evaluate(x_train_gru, y_train_gru)

plot_loss_curves(history)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8735 - loss: 0.3447

# %%
classes = ["COPD" ,"Bronchiolitis ", "Pneumoina", "URTI", "Healthy"]
preds = gru_model.predict(x_test_gru)
classpreds = [np.argmax(t) for t in preds ]
y_testclass = [np.argmax(t) for t in y_test_gru]
cm = confusion_matrix(y_testclass, classpreds)
plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
ax = sns.heatmap(cm, cmap='Blues', annot=True, fmt='d', xticklabels=classes, yticklabels=classes)
plt.title('')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step

# %%
print(classification_report(y_testclass, classpreds, target_names=classes))
# Out:
#                 precision    recall  f1-score   support
#
#           COPD       1.00      0.96      0.98        25
# Bronchiolitis        0.90      1.00      0.95         9
#      Pneumoina       0.89      0.80      0.84        10
#           URTI       1.00      0.25      0.40         4
#        Healthy       0.81      1.00      0.89        17
#
#       accuracy                           0.91        65
#      macro avg       0.92      0.80      0.81        65
#   weighted avg       0.92      0.91      0.90        65

# %%
def gru_diagnosis_prediction(test_audio):
    data_x, sampling_rate = librosa.load(test_audio)
    data_x = stretch (data_x,1.2)

    features = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=52).T,axis = 0)

    features = features.reshape(1,52)

    test_pred = gru_model.predict(np.expand_dims(features, axis = 1))
    classpreds = classes[np.argmax(test_pred[0], axis=1)[0]]
    confidence = test_pred.T[test_pred[0].mean(axis=0).argmax()].mean()

    print (classpreds , confidence)

# %%
val = []
dir_ = r"D:\Respiratory_Sound_Database\Respiratory_Sound_Database\AUDIOS\104_1b1_Ll_sc_Litt3200.wav"
features = 52

data_x, sampling_rate = librosa.load(dir_, res_type='kaiser_fast') # Use dir_ directly
mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T, axis=0)
val.append(mfccs)
val = np.expand_dims(np.array(val), axis=0) 
print(val.shape) # Output: (1, 1, 52)
# Out:
# (1, 1, 52)

# %%
classes[np.argmax(gru_model.predict(val))]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 'COPD'
